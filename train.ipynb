# %% [markdown]
# <a href="https://colab.research.google.com/github/pimang62/aiconnect-GANdetector/blob/main/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/aiconnect
# Out:
# /content/drive/MyDrive/aiconnect

# %%
# unzip
# !unzip baseline.zip -d /content/
# !unzip train.zip -d /content/baseline/
# !unzip test.zip -d /content/baseline/
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: /content/baseline/test/images/test_53349.png
#   inflating: /content/baseline/test/images/test_53350.png
#   inflating: /content/baseline/test/images/test_53351.png
#   inflating: /content/baseline/test/images/test_53352.png
#   inflating: /content/baseline/test/images/test_53353.png
#   inflating: /content/baseline/test/images/test_53354.png
#   inflating: /content/baseline/test/images/test_53355.png
#   inflating: /content/baseline/test/images/test_53356.png
#   inflating: /content/baseline/test/images/test_53357.png
#   inflating: /content/baseline/test/images/test_53358.png
#   inflating: /content/baseline/test/images/test_53359.png
#   inflating: /content/baseline/test/images/test_53360.png
#   inflating: /content/baseline/test/images/test_53361.png
#   inflating: /content/baseline/test/images/test_53362.png
#   inflating: /content/baseline/test/images/test_53363.png
#   inflating: /content/baseline/test/images/test_53364.png
# ...

# %%
# !pip install timm wandb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 20.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 52.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 55.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.6/215.6 kB 19.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.2 MB/s eta 0:00:00
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=623a53bf993b7463f4b612a6ed3a3f023696e22f71f602260d0ec990c7c930bc
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# ...

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# ## Code setting
#
# ---
#
# 1. train_config.yaml
#
# * DIRECTORY:
#   dataset: #{DATA_DIR}/train
#   * {DATA_DIR} → /content/baseline
#
# * learning_rate : 4.0e-4
# * n_epochs : 2
# * batch_size : 25(32)
#
#
# 2. predict_config.yaml
#
# * DIRECTORY:
#   dataset: #{DATA_DIR}/test/images
#   sample_submission_path : #{DATA_DIR}/test/sample_submission.csv
#   * {DATA_DIR} → /content/baseline
#
# * TRAIN:
#   train_serial: #'YYYYMMDD_HHMMSS'
#   * *After training, you might get it from 'result' directory
#   * 'YYYYMMDD_HHMMSS' → (ex) '20230705_150000'

# %%
# %cd /content/baseline
# Out:
# /content/baseline

# %%
# !python3 train.py
# Out:
# ...
# Train 0/2
# 100% 437/437 [1:02:09<00:00,  8.53s/it]
# Val 0/2
# 100% 187/187 [05:36<00:00,  1.80s/it]
# Train 1/2
# 100% 437/437 [1:02:44<00:00,  8.61s/it]
# Val 1/2
# 100% 187/187 [05:47<00:00,  1.86s/it]

# %%
# !python3 predict.py
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# ...
