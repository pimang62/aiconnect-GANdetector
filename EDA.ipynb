# %% [markdown]
# <a href="https://colab.research.google.com/github/pimang62/aiconnect-GANdetector/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/aiconnect/baseline/train
# Out:
# /content/drive/MyDrive/aiconnect/baseline/train

# %%
# !ls
# Out:
# data  fake_images  real_images

# %%
#!mkdir 디렉토리2

# %%
#!cp -a 디렉토리1/. 디렉토리2/

# %%
#%cd /content/drive/MyDrive/aiconnect/baseline/train/data
# Out:
# /content/drive/MyDrive/aiconnect/baseline/train/data

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from glob import glob

fake_images = glob('/content/drive/MyDrive/aiconnect/baseline/train/fake_images/fake_*.png')
real_images = glob('/content/drive/MyDrive/aiconnect/baseline/train/real_images/real_*.png')
labels = [1] * len(fake_images) + [0] * len(real_images)

# %%
print(len(fake_images))
print(len(real_images))
# Out:
# 10000
# 10000

# %%
from PIL import Image
# 이미지 파일 열기
fake_image = Image.open(fake_images[0])

# 이미지 시각화
plt.imshow(fake_image)
plt.axis('off')
plt.show()
